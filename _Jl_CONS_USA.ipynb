# %%
using DataFrames, CSV;
# Lectura de datos
CONS_USA = CSV.read("CONS_USA.csv", DataFrame);

# %%
# Análisis exploratorio (EDA)
show(describe(CONS_USA))
# Out:
# 3×7 DataFrame
#  Row │ variable  mean     min     median   max      nmissing  eltype
#      │ Symbol    Float64  Real    Float64  Real     Int64     DataType
# ─────┼─────────────────────────────────────────────────────────────────
#    1 │ obs       1987.0   1959     1987.0   2015           0  Int64
#    2 │ C         5746.61  1840.5   5183.6  11214.7         0  Float64
#    3 │ Y         6418.35  2092.1   5811.1  12343.2         0  Float64

# %%
using Plots
C = CONS_USA[:,2]
Y = CONS_USA[:,3]
scatter(Y, C)
xlabel!("Y")
ylabel!("C")
